# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", 1000) 
pd.set_option("display.max_rows", 1000)
url = 'https://github.com/sambiner/LMU-Datathon-2024/blob/main/EPA%20Contract%20Data/FY2008_068_Contracts_Full_20240213_1.csv?raw=true'
df = pd.read_csv(url, low_memory=False)
#df.select_dtypes(include=np.number)
#df.select_dtypes(include=np.number).columns.tolist()

print('n')
# Out:
# n

# %%
import matplotlib.pyplot as plt
import pandas as pd
top_naics_codes = df.groupby('naics_code')['current_total_value_of_award'].nlargest(5)
result_df = pd.merge(top_naics_codes, df[['naics_code', 'naics_description']], on='naics_code', how='left')
result_df = result_df.drop_duplicates(subset='naics_code').sort_values(by=['current_total_value_of_award'], ascending= False)
result_df = result_df.head(5)
result_df1 = result_df.tail(5)
print(result_df)
# Assuming 'result_df' contains the result obtained from the previous step
# If not, replace it with the appropriate DataFrame containing 'naics_code', 'current_total_value_of_award', and 'naics_description'

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
result_df.plot(kind='bar', x='naics_description', y='current_total_value_of_award', ax=ax, color='skyblue', edgecolor='black')


# Set labels and title
ax.set_xlabel('NAICS Description')
ax.set_ylabel('Total Value of Awards')
ax.set_title('Top Industries with the Most Awards')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()
# Out:
#        naics_code  current_total_value_of_award  \
# 13735    562910.0                  2.941856e+08
# 2021     541330.0                  1.297494e+08
# 1575     517110.0                  8.862189e+07
# 4189     541611.0                  7.575748e+07
# 3234     541512.0                  6.584077e+07
#
#                                        naics_description
# 13735                               REMEDIATION SERVICES
# 2021                                ENGINEERING SERVICES
# 1575                   WIRED TELECOMMUNICATIONS CARRIERS
# 4189   ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 3234                    COMPUTER SYSTEMS DESIGN SERVICES

# %%
import matplotlib.pyplot as plt
import pandas as pd
top_naics_codes = df.groupby('naics_code')['current_total_value_of_award'].nlargest(5)
result_df = pd.merge(top_naics_codes, df[['naics_code', 'naics_description']], on='naics_code', how='left')
result_df = result_df.drop_duplicates(subset='naics_code').sort_values(by=['current_total_value_of_award'], ascending= False)
result_df0 = result_df.head(5)
result_df1 = result_df.tail(5)

# Assuming 'result_df' contains the result obtained from the previous step
# If not, replace it with the appropriate DataFrame containing 'naics_code', 'current_total_value_of_award', and 'naics_description'

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
result_df1.plot(kind='bar', x='naics_description', y='current_total_value_of_award', ax=ax, color='skyblue', edgecolor='black')


# Set labels and title
ax.set_xlabel('NAICS Description')
ax.set_ylabel('Total Value of Awards')
ax.set_title('Top Industries with the Most Awards')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %%
import pandas as pd
# Assuming 'df' is your DataFrame

# Count occurrences of each value in 'minority_owned_business'
minority_counts = df['minority_owned_business'].value_counts()

# Create a DataFrame with counts and reset the index
result_minority = pd.DataFrame({'count': minority_counts}).reset_index()

# Rename the columns for clarity
result_minority.columns = ['minority_owned_business', 'count']

result_minority_t = df[df['minority_owned_business'].str.lower().eq('t')]

# Group by 'naics_description' and count occurrences
grouped_result = result_minority_t.groupby('naics_description')['minority_owned_business'].count().reset_index(name='count')

grouped_result_sorted = grouped_result.sort_values(by='count', ascending=False).head(5)

grouped_result_sorted1 = grouped_result.sort_values(by='count', ascending=False).tail(5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'grouped_result' is your DataFrame containing the grouped counts

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
grouped_result_sorted.plot(kind='bar', x='naics_description', y='count', ax=ax, color='skyblue', edgecolor='black')

# Set labels and title
ax.set_xlabel('NAICS Description', fontsize=12)
ax.set_ylabel('Count of "Minority Owned Business" (t)', fontsize=12)
ax.set_title('Counts of "Minority Owned Business" (t) for Each NAICS Description', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Adjust y-axis labels
plt.yticks(fontsize=10)

# Show the plot

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'grouped_result' is your DataFrame containing the grouped counts

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
grouped_result_sorted1.plot(kind='bar', x='naics_description', y='count', ax=ax, color='skyblue', edgecolor='black')

# Set labels and title
ax.set_xlabel('NAICS Description', fontsize=12)
ax.set_ylabel('Count of "Minority Owned Business" (t)', fontsize=12)
ax.set_title('Counts of "Minority Owned Business" (t) for Each NAICS Description', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Adjust y-axis labels
plt.yticks(fontsize=10)

# Show the plot

plt.show()

# %%
import pandas as pd
# Assuming 'df' is your DataFrame

# Count occurrences of each value in 'minority_owned_business'
minority_counts = df['minority_owned_business'].value_counts()

# Create a DataFrame with counts and reset the index
result_minority = pd.DataFrame({'count': minority_counts}).reset_index()

# Rename the columns for clarity
result_minority.columns = ['minority_owned_business', 'count']

result_minority_t = df[df['minority_owned_business'].str.lower().eq('t')]

# Group by 'naics_description' and count occurrences
grouped_result = result_minority_t.groupby('naics_description')['minority_owned_business'].count().reset_index(name='count')

grouped_result_sorted = grouped_result.sort_values(by='count', ascending=False)

print(grouped_result_sorted)

import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'grouped_result' is your DataFrame containing the grouped counts

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
grouped_result_sorted.plot(kind='bar', x='naics_description', y='count', ax=ax, color='skyblue', edgecolor='black')

# Set labels and title
ax.set_xlabel('NAICS Description', fontsize=12)
ax.set_ylabel('Count of "Minority Owned Business" (t)', fontsize=12)
ax.set_title('Counts of "Minority Owned Business" (t) for Each NAICS Description', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Adjust y-axis labels
plt.yticks(fontsize=10)

# Show the plot

plt.show()
# Out:
#                                     naics_description  count
# 34                               REMEDIATION SERVICES    173
# 3   ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...     64
# 36  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...     49
# 28                    OTHER COMPUTER RELATED SERVICES     46
# 14                  ENVIRONMENTAL CONSULTING SERVICES     40
# 11               CUSTOM COMPUTER PROGRAMMING SERVICES     28
# 15                        FACILITIES SUPPORT SERVICES     26
# 8                    COMPUTER SYSTEMS DESIGN SERVICES     24
# 0   ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...     22
# 23                MOTION PICTURE AND VIDEO PRODUCTION     17
# 6   COMMERCIAL AND INSTITUTIONAL BUILDING CONSTRUC...     13
# 38                SECURITY GUARDS AND PATROL SERVICES     13
# 4      ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING      9
# 18  HUMAN RESOURCES CONSULTING SERVICES (2007), HU...      5
# ...

# %%
import pandas as pd
# Assuming 'df' is your DataFrame

# Count occurrences of each value in 'minority_owned_business'
woman_owned_business_counts = df['woman_owned_business'].value_counts()

# Create a DataFrame with counts and reset the index
result_woman_owned_business = pd.DataFrame({'count': woman_owned_business_counts}).reset_index()

# Rename the columns for clarity
result_woman_owned_business.columns = ['woman_owned_business', 'count']

result_woman_owned_business_t = df[df['woman_owned_business'].str.lower().eq('t')]

# Group by 'naics_description' and count occurrences
grouped_woman_owned_business = result_woman_owned_business_t.groupby('naics_description')['woman_owned_business'].count().reset_index(name='count')

grouped_woman_owned_business_sorted = grouped_woman_owned_business.sort_values(by='count', ascending=False).head(5)
grouped_woman_owned_business_sorted1 = grouped_woman_owned_business.sort_values(by='count', ascending=False).tail(5)


import matplotlib.pyplot as plt

# Assuming 'grouped_result' is your DataFrame containing the grouped counts

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
grouped_woman_owned_business_sorted.plot(kind='bar', x='naics_description', y='count', ax=ax, color='skyblue', edgecolor='black')

# Set labels and title
ax.set_xlabel('NAICS Description', fontsize=12)
ax.set_ylabel('Count of "woman_owned_business" (t)', fontsize=12)
ax.set_title('Counts of "woman_owned_business" (t) for Each NAICS Description', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Adjust y-axis labels
plt.yticks(fontsize=10)

# Show the plot

plt.show()

# %%
import pandas as pd
# Assuming 'df' is your DataFrame

# Count occurrences of each value in 'minority_owned_business'
women_owned_small_business_counts = df['women_owned_small_business'].value_counts()

# Create a DataFrame with counts and reset the index
result_women_owned_small_business = pd.DataFrame({'count': women_owned_small_business_counts}).reset_index()

# Rename the columns for clarity
result_women_owned_small_business.columns = ['women_owned_small_business', 'count']

result_women_owned_small_business_t = df[df['women_owned_small_business'].str.lower().eq('t')]

# Group by 'naics_description' and count occurrences
grouped_women_owned_small_business = result_women_owned_small_business_t.groupby('naics_description')['women_owned_small_business'].count().reset_index(name='count')

grouped_women_owned_small_business_sorted = grouped_women_owned_small_business.sort_values(by='count', ascending=False)



import matplotlib.pyplot as plt

# Assuming 'grouped_result' is your DataFrame containing the grouped counts

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Create a bar plot
grouped_woman_owned_business_sorted.plot(kind='bar', x='naics_description', y='count', ax=ax, color='skyblue', edgecolor='black')

# Set labels and title
ax.set_xlabel('NAICS Description', fontsize=12)
ax.set_ylabel('Count of "grouped_woman_owned_business" (t)', fontsize=12)
ax.set_title('Counts of "grouped_woman_owned_business" (t) for Each NAICS Description', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=10)

# Adjust y-axis labels
plt.yticks(fontsize=10)

# Show the plot
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60')])
